# %% [markdown]
# 論文<br>
# https://arxiv.org/abs/2303.02506<br>
# <br>
# GitHub<br>
# https://github.com/NVlabs/prismer<br>
# <br>
# <a href="https://colab.research.google.com/github/kaz12tech/ai_demos/blob/master/Prismer_demo.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # setup environment

# %% [markdown]
# ## git clone

# %%
# %cd /content

# !git clone https://github.com/NVlabs/prismer.git

# %cd /content/prismer
# Commits on Mar 22, 2023
# !git checkout 2fa4f8da37465eaf756d3bd4bc94dc44c15cc675

# %% [markdown]
# ## install libraries

# %%
# %cd /content/prismer
# !pip install -r requirements.txt

# %%
# %cd /content/prismer/experts/segmentation/mask2former/modeling/pixel_decoder/ops

# !sh make.sh

# %% [markdown]
# ## import libraries

# %%
# %cd /content/prismer

# %% [markdown]
# # download pretrain models

# %%
# %cd /content/prismer

# !python download_checkpoints.py --download_models=True

# %%
# !python demo.py --exp_name prismer_base
